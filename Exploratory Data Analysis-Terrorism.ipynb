# %% [markdown]
# ****Task #4: Exploratory Data Analysis - Terrorism****
#
# - Perform xploratory Data Analysis on Global Terrorism dataset.
# - Try to find out hot zones of terrorism.
# - Drive all security issues and insights while exploring the data.

# %% [markdown]
# # 1. Import Libraries

# %% [markdown]
# ## 1.1 Import Numpy and Pandas Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1.2 Import Graphs

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 1.3 Import Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Reading and Understanding the Data

# %% [markdown]
# ## 2.1 Reading Data

# %%
terror_data = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='latin-1')
print("Data imported successfully")

terror_data.head()
# Out:
# Data imported successfully
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ## 2.2 Understanding Data

# %% [markdown]
# ### 2.2.1 Checking Shape of Data

# %%
terror_data.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### 2.2.2 Checking Data Types

# %%
terror_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
terror_data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# ## 2.3 Data Cleaning

# %% [markdown]
# ### 2.3.1 Renaming Data Columns

# %%
# Checking Columns

terror_data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
# Renaming Columns

terror_data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','gname':'Group','country_txt':'Country',
                            'region_txt':'Region','provstate':'State','city':'City','summary':'Summary',
                            'latitude':'Latitude', 'longitude':'Longitude','attacktype1_txt':'AttackType',
                            'targtype1_txt':'TargetType','weaptype1_txt':'Weapon','nkill':'Kill',
                             'nwound':'Wound','motive':'Motive','target1':'Target1'},inplace=True)

# %%
terror_data = terror_data[['Year','Month','Day','Country','State','Region','City','Latitude','Longitude',"AttackType",'Kill',
               'Wound','Target1','Summary','Group','TargetType','Weapon','Motive']]

# %%
# Checking shape of new data

terror_data.shape
# Out:
# (181691, 18)

# %%
terror_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181691 non-null  int64
#  1   Month       181691 non-null  int64
#  2   Day         181691 non-null  int64
#  3   Country     181691 non-null  object
#  4   State       181270 non-null  object
#  5   Region      181691 non-null  object
#  6   City        181257 non-null  object
#  7   Latitude    177135 non-null  float64
#  8   Longitude   177134 non-null  float64
#  9   AttackType  181691 non-null  object
#  10  Kill        171378 non-null  float64
#  11  Wound       165380 non-null  float64
#  12  Target1     181055 non-null  object
#  13  Summary     115562 non-null  object
#  14  Group       181691 non-null  object
#  15  TargetType  181691 non-null  object
#  16  Weapon      181691 non-null  object
#  17  Motive      50561 non-null   object
# dtypes: float64(4), int64(3), object(11)
# memory usage: 25.0+ MB

# %% [markdown]
# ### 2.3.2 Null Value Treatment

# %%
# Checking Null Values

terror_data.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# State            421
# Region             0
# City             434
# Latitude        4556
# Longitude       4557
# AttackType         0
# Kill           10313
# Wound          16311
# Target1          636
# Summary        66129
# Group              0
# TargetType         0
# Weapon             0
# Motive        131130
# dtype: int64

# %%
# Fixing Null Values

terror_data['State']=terror_data['State'].fillna('Unknown')
terror_data['City']=terror_data['City'].fillna('Unknown')
terror_data['Target1']=terror_data['Target1'].fillna('Others')
terror_data['Motive']=terror_data['Motive'].fillna('Others')
terror_data['Summary']=terror_data['Motive'].fillna('NA')
terror_data['Wound'] = terror_data['Wound'].fillna(0)
terror_data['Kill'] = terror_data['Kill'].fillna(0)
terror_data['Latitude'].fillna(int(terror_data['Latitude'].mean()), inplace=True)
terror_data['Longitude'].fillna(int(terror_data['Longitude'].mean()), inplace=True)

# %%
# Creating new column as casaualties

terror_data['Casualties'] = terror_data['Wound'] + terror_data['Kill']

# %%
# Formating the Column

terror_data.replace( {"Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)": "Vehicle"},inplace = True)

# %%
terror_data.isnull().sum()
# Out:
# Year          0
# Month         0
# Day           0
# Country       0
# State         0
# Region        0
# City          0
# Latitude      0
# Longitude     0
# AttackType    0
# Kill          0
# Wound         0
# Target1       0
# Summary       0
# Group         0
# TargetType    0
# Weapon        0
# Motive        0
# Casualties    0
# dtype: int64

# %%
terror_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181691 non-null  int64
#  1   Month       181691 non-null  int64
#  2   Day         181691 non-null  int64
#  3   Country     181691 non-null  object
#  4   State       181691 non-null  object
#  5   Region      181691 non-null  object
#  6   City        181691 non-null  object
#  7   Latitude    181691 non-null  float64
#  8   Longitude   181691 non-null  float64
#  9   AttackType  181691 non-null  object
#  10  Kill        181691 non-null  float64
#  11  Wound       181691 non-null  float64
#  12  Target1     181691 non-null  object
#  13  Summary     181691 non-null  object
#  14  Group       181691 non-null  object
#  15  TargetType  181691 non-null  object
#  16  Weapon      181691 non-null  object
#  17  Motive      181691 non-null  object
#  18  Casualties  181691 non-null  float64
# dtypes: float64(5), int64(3), object(11)
# memory usage: 26.3+ MB

# %%
terror_data.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644      23.485847
# std        13.259430       3.388303       8.814045      18.335112
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.849620
# 50%      2009.000000       6.000000      15.000000      31.126646
# 75%      2014.000000       9.000000      23.000000      34.538560
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude           Kill          Wound     Casualties
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586782e+02       2.266860       2.883296       5.150156
# std    2.021946e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# 25%    1.231572e+00       0.000000       0.000000       0.000000
# 50%    4.314357e+01       0.000000       0.000000       1.000000
# 75%    6.835734e+01       2.000000       2.000000       4.000000
# max    1.793667e+02    1570.000000    8191.000000    9574.000000

# %% [markdown]
# ## 2.4 Reading Final Data

# %%
terror_data.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic  Unknown  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  Kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   0.0
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   0.0
#
#    Wound                  Target1 Summary                               Group  \
# 0    0.0             Julio Guzman  Others                              MANO-D
# 1    0.0  Nadine Chaval, daughter  Others  23rd of September Communist League
# 2    0.0                 Employee  Others                             Unknown
# 3    0.0             U.S. Embassy  Others                             Unknown
# 4    0.0           U.S. Consulate  Others                             Unknown
#
#                     TargetType      Weapon  Motive  Casualties
# 0  Private Citizens & Property     Unknown  Others         1.0
# 1      Government (Diplomatic)     Unknown  Others         0.0
# 2          Journalists & Media     Unknown  Others         1.0
# 3      Government (Diplomatic)  Explosives  Others         0.0
# 4      Government (Diplomatic)  Incendiary  Others         0.0

# %% [markdown]
# # 3. Visulizing the Data

# %% [markdown]
# ## 3.1 Correlation in the Data

# %%
cor = terror_data.corr()
plt.figure(figsize = (8,5))
plt.title('Correaltion among other variables',fontdict={'fontsize':20,'fontweight':5,'color':'green'})
sns.heatmap(cor, annot = True)
plt.show()

# %%
terror_data1 = terror_data.corr().abs().unstack().sort_values(ascending=False).drop_duplicates()
terror_data1
# Out:
# Casualties  Casualties    1.000000
#             Kill          0.976405
#             Wound         0.974784
# Wound       Kill          0.903594
# dtype: float64

# %% [markdown]
# ## 3.2 Column Wise Data Analysis

# %% [markdown]
# ## 3.2.1 Weapon Types

# %%
plt.figure(figsize=(10,5))
sns.countplot(terror_data['Weapon'],order = terror_data['Weapon'].value_counts().index,palette='hsv')
plt.xticks(rotation = 60)
plt.title('Weapon Types',fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("Weapon Count", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.xlabel("Weapons", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.show()

# %% [markdown]
# ## 3.2.2 Year Wise Terror Attack

# %%
plt.figure(figsize=(18,10))
sns.barplot(x=terror_data['Year'].unique(),y= terror_data['Year'].value_counts().sort_index(),palette= ["#7fcdbb","#edf8b1"])
plt.xticks(rotation = 50)
plt.title('Year Wise Terror Attack',fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("No of Terror Attacks", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.xlabel("Year", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.show()

# %% [markdown]
# ## 3.3 Month Wise Attacks

# %%
plt.figure(figsize=(10,5))
sns.countplot(terror_data['Month'],order = terror_data['Month'].value_counts().sort_index().index,palette=['#432371',"#FAAE7B"])
plt.xticks(rotation = 60)
plt.title('Month Wise Attacks',fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("No of Terror Attacks", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.xlabel("Month", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.show()

# %% [markdown]
# ## 3.4 Day Wise Attacks

# %%
plt.figure(figsize=(10,5))
sns.countplot(terror_data['Day'],order = terror_data['Day'].value_counts().sort_index().index,palette='Set3')
plt.xticks(rotation = 60)
plt.title('Day Wise Attacks',fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("No of Terror Attacks", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.xlabel("Day", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.show()

# %% [markdown]
# ## 3.5 Year Wise People Died In Attack

# %%
terror_data.groupby(['Year'])[['Year','Kill']].sum().plot(kind='bar',figsize=(20,10),legend=True,color = 'green')
plt.title('People Died In Attack', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel('No of People Died Due To Attack', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xlabel("Year",fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.show()

# %% [markdown]
# ## 3.6 Year Wise Casualties In Attack

# %%
terror_data.groupby(['Year'])[['Year','Casualties']].sum().plot(kind='bar',figsize=(20,10),color='pink')
plt.title('No of Causalties', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel('No of People', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xlabel("Attack Type",fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ## 3.7 Top Attacked Countries

# %%
plt.figure(figsize = (20,9))
sns.countplot((terror_data['Country']), order=terror_data['Country'].value_counts().iloc[:31].index,palette='Set2')
plt.xticks(rotation = 90)
plt.title('Top Attacked Countries',fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("No of Terror Attacks", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.xlabel("Country", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.show()

# %% [markdown]
# ## 3.8 Top Attacked Cities

# %%
plt.figure(figsize = (20,9))
sns.countplot((terror_data['City']), order=terror_data['City'].value_counts().iloc[:31].index,palette="hsv")
plt.xticks(rotation = 90)
plt.title('Top Attacked Cities',fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("No of Terror Attacks", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.xlabel("Cities", fontdict={'fontsize':20,'fontweight':15,'color':'green'})
plt.show()

# %% [markdown]
# ## 3.9 Attack Type

# %%
terror_data['AttackType'].value_counts().plot(kind='bar',figsize=(20,10),color='magenta')
plt.title('Attack Type', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel('No of Attack', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xlabel("Attack Type",fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ## 3.10 No. of People Killed By Different Attack

# %%
terror_data.groupby(['AttackType'])[['AttackType','Kill']].sum().plot(kind='bar',figsize=(20,10),color = 'darkblue')
plt.title('No of People Killed', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel('No of People', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xlabel("Attack Type",fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ## 3.11 No of People Wounded By Different Attack

# %%
terror_data.groupby(['AttackType'])[['AttackType','Wound']].sum().plot(kind='bar',figsize=(20,10))
plt.title('No of People Wounded', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel('No of People', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xlabel("Attack Type",fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ## 3.12 No of Casualties By Attack

# %%
terror_data.groupby(['AttackType'])[['AttackType','Casualties']].sum().plot(kind='bar',figsize=(20,10),color='red')
plt.title('No of Causalties', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel('No of People', fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xlabel("Attack Type",fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# ## 3.13 Different Targets of Attack

# %%
plt.figure(figsize = (20,9))
sns.countplot(terror_data["TargetType"],order=terror_data['TargetType'].value_counts().index,palette="gist_heat",edgecolor=sns.color_palette("mako"));
plt.xticks(rotation=90)
plt.xlabel("Target of the Attack", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("No of Attack", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.title("Target Type", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## 3.14 Top Terrorist Group

# %%
terror_data['Group'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 Terrorist Group Attack", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xlabel("Terrorist Group Name", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("Attack number", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## 3.16 Top 10 terrorist group attack

# %%
terror_data[['Group','Kill']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('Kill',ascending=False).head(10).plot(kind='bar',color='yellow',figsize=(20,10))
plt.title("Top 10 terrorist group attack", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xlabel("Terrorist group name", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.ylabel("No of killed people", fontdict={'fontsize':20,'fontweight':5,'color':'green'})
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # 4. Summary

# %%
terror_data=terror_data[['Group','Country','Kill','Wound','Casualties']]
terror_data=terror_data.groupby(['Group','Country'],axis=0).sum().sort_values(['Kill','Wound','Casualties'],ascending=False).drop('Unknown').reset_index().head(10)
terror_data
# Out:
#                                               Group      Country     Kill  \
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 1                                           Taliban  Afghanistan  29269.0
# 2                                        Boko Haram      Nigeria  16917.0
# 3                                 Shining Path (SL)         Peru  11595.0
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 5                                        Al-Shabaab      Somalia   8176.0
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0
# 8                 Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 9                   Tehrik-i-Taliban Pakistan (TTP)     Pakistan   6014.0
#
#      Wound  Casualties
# 0  23697.0     54755.0
# 1  27871.0     57140.0
# 2   7671.0     24588.0
# 3   3030.0     14625.0
# 4  10991.0     21919.0
# 5   6025.0     14201.0
# 6   4049.0     12068.0
# 7   4031.0     10914.0
# 8    728.0      7358.0
# 9   9518.0     15532.0

# %%
Wounded = terror_data.loc[:,'Wound']
Killed = terror_data.loc[:,'Kill']
Casualities = terror_data.loc[:,'Casualties']
print('Number of people wounded by terror attack:', int(sum(Wounded.dropna())))
print('Number of people killed by terror attack:', int(sum(Killed.dropna())))
print('Number of people casualities by terror attack:', int(sum(Casualities.dropna())))
# Out:
# Number of people wounded by terror attack: 97611
# Number of people killed by terror attack: 135489
# Number of people casualities by terror attack: 233100

# %%
Country_Most_Kill = terror_data.pivot_table(columns='Country', values='Kill', aggfunc='sum')
Country_Most_Kill
# Out:
# Country  Afghanistan  El Salvador     Iraq  Nicaragua  Nigeria  Pakistan  \
# Kill         29269.0       8019.0  31058.0     6630.0  16917.0    6014.0
#
# Country     Peru  Somalia  Sri Lanka   Syria
# Kill     11595.0   8176.0    10928.0  6883.0

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# - Kil,Wound,Casualties are moderately correlated.
# - Country with the most attacks: Iraq
# - City with the most attacks: Baghdad
# - Region with the most attacks: Middle East & North Africa
# - Year with the most attacks: 2014
# - Month with the most attacks: 5
# - Most attack happens on: 15th of every Month
# - Group with the most attacks: Taliban
# - Group with the most killings: Islamic State of Iraq and the Levant (ISIL)
# - Most frequent Weapons used for the attack: Explosives
# - Most Attack Types: Bombing/Explosion
# - Most frequent target of attack: Private Citizens & Property

# %% [markdown]
# # 6. Recomendations

# %% [markdown]
# - Iraq is the affected country by terror attacks.
# - Middle East and North Africa are safe place to travel.
# - The Year 2014 was worst affected year due to terror attack and post that there is a decrease in terror attacks.
# - People should avoid travelling on either in 5 month or 15th of every month due to high risk of terror on these ocassion.
# - The ISIL and Taliban are most dangerous group so strict actions need to taken against these group to reduce terror attacks.
# - The Explosives are most widely weapon to carry out terror attacks as people in their production needs to be punished.
# - The security for the Private Citizens & Property needs to monitored as they are most affected durint terror attack
